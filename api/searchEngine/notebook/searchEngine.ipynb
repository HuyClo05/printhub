# %%
# Setup: Add project root to Python path
import sys
import os

notebook_dir = os.path.dirname(os.path.abspath(globals().get('__file__', os.getcwd())))
project_root = os.path.abspath(os.path.join(notebook_dir, '..', '..'))

if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(f"Notebook dir: {notebook_dir}")
print(f"Project root: {project_root}")
# Out:
# Notebook dir: d:\MultiImagesResolution\340\csc-340-vue\printhub\api\searchEngine
# Project root: d:\MultiImagesResolution\340\csc-340-vue\printhub

# %%
# Now you can import from anywhere:
from api.firebase_data import models_db

# %%
models = models_db.collection("printables").stream()
print(f"Found {len(list(models))} printables in the database.")
# Out:
# Found 8361 printables in the database.
